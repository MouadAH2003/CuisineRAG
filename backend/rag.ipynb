# %%
"""
pip install python-docx
pip install tika
pip install sentence-transformers


"""
# Out:
# '\npip install python-docx\npip install tika\npip install sentence-transformers\n\n\n'

# %%
import os
import json
import docx
from tika import parser
from PyPDF2 import PdfReader
from sentence_transformers import SentenceTransformer

# %%
def extract_text(file_path):
    # Détecter l'extension du fichier
    file_extension = os.path.splitext(file_path)[1].lower()

    #  PDF
    if file_extension == '.pdf':
        reader = PdfReader(file_path)
        text = ''
        for page in reader.pages:
            text += page.extract_text()
        return text

    #  Word
    elif file_extension == '.docx':
        doc = docx.Document(file_path)
        text = '\n'.join([para.text for para in doc.paragraphs])
        return text

    #  JSON
    elif file_extension == '.json':
        with open(file_path, 'r') as file:
            data = json.load(file)
            return json.dumps(data, indent=4)

    else:
        parsed = parser.from_file(file_path)
        return parsed['content']

# %%
def extract_recipes(directory):
    recipes_dict = {}
    
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            file_path = os.path.join(directory, filename)
            text = extract_text(file_path)
            recipes_dict[os.path.splitext(filename)[0]] = text
    
    return recipes_dict

# %%
def afficher_premiers_elements(dictionnaire, nombre=5):
    for i, (cle, valeur) in enumerate(dictionnaire.items()):
        if i >= nombre:
            break
        print(f"{cle}: {valeur}...")
        print('-'*50)

# %%
# Exemple d'utilisation
directory_path = 'recipes/'
recipes = extract_recipes(directory_path)
#afficher_premiers_elements(recipes, 5)

# %%
len(recipes)
# Out:
# 89

# %%
def embed_chunks(dictionnaire):
    embeddings = []
    model = SentenceTransformer('all-MiniLM-L6-v2')
    for text in dictionnaire.values():
        embedding = model.encode(text)
        embeddings.append(embedding)
    
    return embeddings

# %%
embedded_recipes[:5]
# Out:
# [array([-6.54793680e-02, -3.61366905e-02, -3.34797464e-02,  5.58839552e-02,
#         -2.98765283e-02,  2.68046814e-03,  8.93261284e-03,  2.28367578e-02,
#          5.17046340e-02, -6.61511421e-02,  3.63028347e-02, -7.13784546e-02,
#         -4.97402251e-02, -9.61723104e-02,  9.59252864e-02, -1.17175910e-03,
#          5.89344278e-02,  5.98610006e-03,  1.63500216e-02, -4.88644466e-02,
#          8.82040933e-02, -5.00125960e-02,  2.11932454e-02,  5.15453778e-02,
#          1.23479543e-02,  1.01272844e-01,  6.06285557e-02,  9.42868087e-03,
#         -5.32352850e-02, -1.95661150e-02, -1.50085129e-02, -7.55551644e-03,
#          3.70279513e-02, -2.96007022e-02, -7.75383040e-02,  4.42304723e-02,
#         -3.18507082e-03, -7.42399171e-02,  1.10599220e-01,  5.51228505e-03,
#          2.16745641e-02,  7.86028523e-03,  6.49628043e-02, -9.90224071e-03,
#          3.09084123e-03, -2.25299038e-02,  1.96992755e-02,  1.23342816e-02,
# ...
